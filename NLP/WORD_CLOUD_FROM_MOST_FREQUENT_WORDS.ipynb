# %%
import pandas as pd
import matplotlib.pyplot as plt
add1="C:/Users/ANTHONY/Desktop/Corona_NLP_test.csv"
corona=pd.read_csv(add1)
corona = corona.dropna(subset=['OriginalTweet']) 

corona
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     TRENDING: New Yorkers encounter empty supermar...  Extremely Negative
# 1     When I couldn't find hand sanitizer at Fred Me...            Positive
# ...

# %%
corona_data = corona[corona.Location=="NYC"]
corona_data
# Out:
#       UserName  ScreenName Location     TweetAt  \
# 0            1       44953      NYC  02-03-2020
# 867        868       45820      NYC  12-03-2020
# 1428      1429       46381      NYC  13-03-2020
# 1827      1828       46780      NYC  13-03-2020
# 1933      1934       46886      NYC  13-03-2020
# 2137      2138       47090      NYC  13-03-2020
# 2441      2442       47394      NYC  14-03-2020
# 2463      2464       47416      NYC  14-03-2020
# 3491      3492       48444      NYC  16-03-2020
# 3543      3544       48496      NYC  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     TRENDING: New Yorkers encounter empty supermar...  Extremely Negative
# 867   https://t.co/UIyysVsc1x\r\r\n\r\r\n"This is ab...             Neutral
# 1428  Anxiety levels are high over #Covid_19 The las...            Positive
# 1827  #Covid_19 wasn't real for most Americans until...            Negative
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ANTHONY\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

sw = set(stopwords.words("english"))
clou=""
most_occur=[]
for i in corona_data.OriginalTweet:
    text_tokens = word_tokenize(i)

    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    tokens_with_an = [word for word in tokens_without_sw if word.isalpha()]

    filtered_sentence = (" ").join(tokens_with_an)
    Coun = Counter(filtered_sentence.split())
    x=Coun.most_common()[0][0]
    clou = clou + " " +x
print(clou)
# Out:
#  https This Anxiety stock In Everybody I Dried Want Why

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# Generate the word cloud from the east_of_eden string
cloud_east_of_eden = WordCloud(background_color="white").generate(clou)

# Create a figure of the generated cloud
plt.imshow(cloud_east_of_eden, interpolation='bilinear')  
plt.axis('off')
# Display the figure
plt.show()

# %%
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

sw = set(stopwords.words("english"))
clou=""
most_occur=[]
for i in corona.OriginalTweet:
    
    text_tokens = word_tokenize(i)

    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    tokens_with_an = [word for word in tokens_without_sw if word.isalpha()]

    filtered_sentence = (" ").join(tokens_with_an)
    Coun = Counter(filtered_sentence.split())
    x=Coun.most_common()[0][0]
    clou = clou + " " +x
print(clou)
# Out:
#  https I Find https everyone Do Voting DrTedros I last Best https Panic Went While seats measures food month like sold For gold facemasks prices I When Costco food Coronavirus call Tip Is dollar gt etc Fellow food soap Thread For So Global https Are Tax https The Global crisis ScottMorrisonMP Cuomo online enough thehill US ToiletPaper Come https Breaking LNG BreakingNews business problem coronavirus stock Ok things The amp https Russia Retail Met https folks world https adding CDC If us No us us https These Retailers Hotline Even coronavirus https Wash Coronavirus German The What Roberts https Besides I My https It need We amp Local https Just realDonaldTrump I good toilet So https Metro family Low Due gas One food https The The I I payload Avoid While Shares Ok Former A coming amp seen amp matter https sanitizer Why go CancelEverything store The Any toilet Very paper Fill extra US Ever food A Going CPG bog Well https I https Italy CBCTerry Are LOOK I Remember food I https https fina
# ...

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# Generate the word cloud from the east_of_eden string
cloud_east_of_eden = WordCloud(background_color="white").generate(clou)

# Create a figure of the generated cloud
plt.imshow(cloud_east_of_eden, interpolation='bilinear')  
plt.axis('off')
# Display the figure
plt.show()

# %%
#######################################################################################################

# %%
useless=stopwords.words('english')
corona['OriginalTweet']=corona['OriginalTweet'].apply(lambda x: ''.join([word for word in x.split() if word not in (useless)]))
x=Counter("".join(corona["OriginalTweet"]).split()).most_common(100)
x
# Out:
# [('TRENDING:NewYorkersencounteremptysupermarketshelves(pictured,WegmansBrooklyn),sold-outonlinegrocers(FoodKick,MaxDelivery)#coronavirus-fearingshoppersstockhttps://t.co/Gr76pcrLWhhttps://t.co/ivMKMsqdT1WhenIfindhandsanitizerFredMeyer,Iturned#Amazon.But$114.972packPurell??!!Check#coronavirusconcernsdrivingprices.https://t.co/ygbipBflMYFindprotectlovedones#coronavirus.?#Panicbuyinghits#NewYorkCityanxiousshoppersstockfood&amp;medicalsupplies#healthcareworker30sbecomes#BigApple1stconfirmed#coronaviruspatientOR#Bloombergstagedevent?https://t.co/IASiReGPC4#QAnon#QAnon2018#QAnon2020#Election2020#CDChttps://t.co/29isZOewxu#toiletpaper#dunnypaper#coronavirus#coronavirusaustralia#CoronaVirusUpdate#Covid_19#9News#Corvid19#7NewsMelb#dunnypapergate#CostcoOneweekeveryonebuyingbabymilkpowdernexteveryonebuyingtoiletpaper.https://t.co/ScZryVvsIhDorememberlasttimepaid$2.99gallonregulargasLosAngeles?Pricespumpgoingdown.Alook#coronavirusimpactingprices.4pm@ABC7https://t.co/Pyzq8YMuV5Votingage#coronavir
# ...

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# Generate the word cloud from the east_of_eden string
cloud_east_of_eden = WordCloud(background_color="white").generate(x)

# Create a figure of the generated cloud
plt.imshow(cloud_east_of_eden, interpolation='bilinear')  
plt.axis('off')
# Display the figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-6083aacb47e5> in <module>
#       3
#       4 # Generate the word cloud from the east_of_eden string
# ----> 5 cloud_east_of_eden = WordCloud(background_color="white").generate(x)
#       6
#       7 # Create a figure of the generated cloud
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ...
