# %%
from telegram.ext import *
from telegram import *
import requests
import re



def test_function(update:Update,context:CallbackContext):
    bot.send_message(
    chat_id=update.effective_chat.id,
    text="PODA")

bot=Bot('1809540140:AAEND8ZbXvOEglMpP7YJoCR-U1ChyLq2dlc')
updater = Updater('1809540140:AAEND8ZbXvOEglMpP7YJoCR-U1ChyLq2dlc',use_context=True)  ###  fro updating whatever is in the bot
dp = updater.dispatcher   ##  dispatch the updates

start_value=CommandHandler('Hello',test_function)
dp.add_handler(start_value)   # update send using this dispatcher class

updater.start_polling()

#print(bot.get_me())
# Out:
# Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\ext\updater.py", line 520, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\ext\updater.py", line 471, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\bot.py", line 127, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\bot.py", line 2761, in get_updates
#     result = self._post(
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\bot.py", line 259, in _post
#     return self.request.post(
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\utils\request.py", line 350, in post
# ...

# %%
from telegram.ext import Updater, InlineQueryHandler, CommandHandler
import requests
import re

def get_url():
    contents = requests.get('https://random.dog/woof.json').json()    
    url = contents['url']
    return url

def bop(bot, update):
    url = get_url()
    chat_id = update.message.chat_id
    bot.send_photo(chat_id=chat_id, photo=url)

def main():
    updater = Updater('1875573222:AAGq07KDZYC0625XPwnK-12Oz1ZwD54W1rQ')
    dp = updater.dispatcher
    dp.add_handler(CommandHandler('Hii',bop))
    updater.start_polling()
    updater.idle()

if __name__ == '__main__':
    main()
# Out:
# Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\ext\updater.py", line 520, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\ext\updater.py", line 471, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\bot.py", line 127, in decorator
#     result = func(*args, **kwargs)
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\bot.py", line 2761, in get_updates
#     result = self._post(
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\bot.py", line 259, in _post
#     return self.request.post(
#   File "C:\Users\ANTHONY\anaconda3\lib\site-packages\telegram\utils\request.py", line 350, in post
# ...

# %%
import requests
import json
import configparser as cfg


class telegram_chatbot():

    def __init__(self, config):
        self.token = self.read_token_from_config_file(config)
        self.base = "https://api.telegram.org/bot{}/".format(self.token)

    def get_updates(self, offset=None):
        url = self.base + "getUpdates?timeout=100"
        if offset:
            url = url + "&offset={}".format(offset + 1)
        r = requests.get(url)
        return json.loads(r.content)

    def send_message(self, msg, chat_id):
        url = self.base + "sendMessage?chat_id={}&text={}".format(chat_id, msg)
        if msg is not None:
            requests.get(url)

    def read_token_from_config_file(self, config):
        parser = cfg.ConfigParser()
        parser.read(config)
        return parser.get('creds', 'token')
