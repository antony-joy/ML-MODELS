# %%
import lux
import pandas as pd

# Collecting basic usage statistics for Lux (For more information, see: https://tinyurl.com/logging-consent)
lux.logger = True # Remove this line if you do not want your interactions recorded
df = pd.read_csv("C:/Users/ANTHONY/Desktop/CSV&XLSX/HR_employee_ret.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
HPI = pd.read_csv("https://github.com/lux-org/lux-datasets/blob/master/data/hpi_full.csv?raw=True")

# %%
HPI
# Out:
#      HPIRank      Country                     SubRegion  AvrgLifeExpectancy  \
# 0        110  Afghanistan  Middle East and North Africa                59.7
# 1         13      Albania                Post-communist                77.3
# 2         30      Algeria  Middle East and North Africa                74.3
# 3         19    Argentina                      Americas                75.9
# 4         73      Armenia                Post-communist                74.4
# ..       ...          ...                           ...                 ...
# 135       29    Venezuela                      Americas                73.9
# 136        5      Vietnam                  Asia Pacific                75.5
# 137       94        Yemen  Middle East and North Africa                63.3
# 138       77       Zambia            Sub Saharan Africa                58.4
# 139       99     Zimbabwe            Sub Saharan Africa                53.7
#
# ...

# %%
# !pip install lux

# %%
# !jupyter nbextension install --py luxwidget
# Out:
# Installing C:\Users\ANTHONY\anaconda3\lib\site-packages\luxwidget\nbextension/static -> luxwidget
# Up to date: C:\ProgramData\jupyter\nbextensions\luxwidget\extension.js
# Up to date: C:\ProgramData\jupyter\nbextensions\luxwidget\index.js
# Up to date: C:\ProgramData\jupyter\nbextensions\luxwidget\index.js.map
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable luxwidget --py

# %%
# !jupyter nbextension enable --py luxwidget
# Out:
# Enabling notebook extension luxwidget/extension...
#       - Validating: ok

# %%
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
# -
# Building jupyterlab assets (build:prod:minimize)

# %%
# !jupyter labextension install luxwidget
# Out:
# An error occured.
# Building jupyterlab assets (build:prod:minimize)
# RuntimeError: npm dependencies failed to install
# See the log file for details:  C:\Users\ANTHONY\AppData\Local\Temp\jupyterlab-debug-z3s5gkcp.log

# %%
import lux
import pandas as pd

# Collecting basic usage statistics for Lux (For more information, see: https://tinyurl.com/logging-consent)
lux.logger = True # Remove this line if you do not want your interactions recorded
df = pd.read_csv("C:/Users/ANTHONY/Desktop/CSV&XLSX/HR_employee_ret.csv")

df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...
