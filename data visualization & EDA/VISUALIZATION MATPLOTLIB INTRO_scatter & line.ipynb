# %% [markdown]
# ## Load Sample Data

# %% [markdown]
# ### Load CSV File
# In this part of the video we are loading a file and just assuming it is loading properly.

# %%
# Import libraries
import pandas as pd
import numpy as np

# Load car loan data from a csv file
filename ="C:/Users/ANTHONY/Desktop/CSV&XLSX/car_financing.csv"
df = pd.read_csv(filename)
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
# Let's first start by looking at the car_type column. 
df['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
# Notice that the filter produces a pandas series of True and False values
car_filter = df['car_type']=='Toyota Sienna'

df[car_filter].head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
df['interest_rate'].value_counts()
# Out:
# 0.0290    144
# 0.0390    144
# 0.0359     60
# 0.0702     60
# Name: interest_rate, dtype: int64

# %%
#########33 SEEIGN THE ABOVE FREQUQNCY IN HISTOGRAM
df['interest_rate'].hist()
# Out:
# <AxesSubplot:>

# %%
# Notice that the filter produces a pandas series of True and False values
df[df['interest_rate']==0.0702]
# Out:
#     Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0       1          34689.96     687.23         202.93          484.30
# 1       2          34205.66     687.23         200.10          487.13
# 2       3          33718.53     687.23         197.25          489.98
# 3       4          33228.55     687.23         194.38          492.85
# 4       5          32735.70     687.23         191.50          495.73
# 5       6          32239.97     687.23         188.60          498.63
# 6       7          31741.34     687.23         185.68          501.55
# 7       8          31239.79     687.23         182.75          504.48
# 8       9          30735.31     687.23         179.80          507.43
# 9      10          30227.88     687.23         176.83          510.40
# 10     11          29717.48     687.23         173.84          513.39
# 11     12          29204.09     687.23         170.84          516.39
# ...

# %%
############################### CHECKING NULL VALUES  ################################

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             408 non-null    int64
#  1   Starting Balance  408 non-null    float64
#  2   Repayment         408 non-null    float64
#  3   Interest Paid     408 non-null    float64
#  4   Principal Paid    408 non-null    float64
#  5   New Balance       408 non-null    float64
#  6   term              408 non-null    int64
#  7   interest_rate     408 non-null    float64
#  8   car_type          408 non-null    object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB

# %% [markdown]
# ### PLOTTING

# %%
##############################################      VISUALIZATION   ######################################################

# The inline flag will use the appropriate backend to make figures appear inline in the notebook.  
#################### ie, inside the notebook itself
# %matplotlib inline   

# `plt` is an alias for the `matplotlib.pyplot` module
import matplotlib.pyplot as plt

# import seaborn library (wrapper of matplotlib)
import seaborn as sns

# %%
########### inbuilt help command
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
################################################### LINE PLOT  ################################################3
# Not the prettiest plot
plt.plot(df.Month,df ['Interest Paid'])

# %%
# You can also plot another line on the same graph
plt.plot(df.Month,df ['Interest Paid'])
plt.plot(df.Month, df ['Principal Paid'])

# %%
################################################### SCATTER PLOT  ################################################

plt.scatter(df.Month,df ['Interest Paid'])

# %% [markdown]
# ### Choose Figure Style

# %%
# Our style choices
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# We are currently using default plot 
# so this will not change much about our plot
plt.style.use('fivethirtyeight')

plt.plot(df.Month,df ['Interest Paid'])
plt.plot(df.Month, df ['Principal Paid'])

# %% [markdown]
# ## Setting plot titles, labels, and limits

# %%
plt.plot(df.Month,df ['Interest Paid'],c= 'k')
plt.plot(df.Month, df ['Principal Paid'],c= 'b')

plt.xlim(left=1,right=70)
plt.ylim(bottom=0,top=1000)
# Out:
# (0.0, 1000.0)

# %%
plt.style.use('classic')

plt.plot(df.Month,df ['Interest Paid'],c= 'k')
plt.plot(df.Month, df ['Principal Paid'],c= 'b')


plt.xlabel('Month')
plt.ylabel('Dollars')
plt.title('Interest and Principal Paid Each Month')
# Out:
# Text(0.5, 1.0, 'Interest and Principal Paid Each Month')

# %%
plt.plot(df.Month,df ['Interest Paid'],c= 'r')
plt.plot(df.Month, df ['Principal Paid'],c= 'b')



plt.xlabel('Month', fontsize = 15)
plt.ylabel('Dollars', fontsize = 15)
plt.title('Interest and Principal Paid Each Month', fontsize = 15)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 15)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1)
plt.plot(df.Month,df ['Interest Paid'],c= 'k')
plt.plot(df.Month, df ['Principal Paid'],c= 'b')


plt.xlabel('Month')
plt.ylabel('Dollars')
plt.title('Interest and Principal Paid Each Month')
# Out:
# Text(0.5, 1.0, 'Interest and Principal Paid Each Month')

# %% [markdown]
# ### MARKER TYPE

# %%
plt.plot(df.Month,df ['Interest Paid'],c = 'k', marker = '.', markersize = 10)
plt.plot(df.Month, df ['Principal Paid'],c = 'b', marker = '.', markersize = 10)

# %% [markdown]
# ### GRID

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1)
plt.plot(df.Month,df ['Interest Paid'],c= 'k')
plt.plot(df.Month, df ['Principal Paid'],c= 'b')


plt.xlabel('Month')
plt.ylabel('Dollars')
plt.title('Interest and Principal Paid Each Month')

plt.grid()

# %%
# only horizontal grid lines
plt.plot(df.Month,df ['Interest Paid'],c= 'k')
plt.plot(df.Month, df ['Principal Paid'],c= 'b')

plt.grid(axis = 'y')
