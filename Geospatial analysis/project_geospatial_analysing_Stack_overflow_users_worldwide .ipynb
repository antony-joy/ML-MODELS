# %%
address='https://raw.githubusercontent.com/antony-joy/Data_sets/main/Stack_overflow%20usage_statistics.csv'
# Import pandas
import pandas as pd

# Import so_survey_csv into so_survey_df
so_survey_df = pd.read_csv(address)

print(so_survey_df.dtypes)
so_survey_df
# Out:
# SurveyDate                     object
# FormalEducation                object
# ConvertedSalary               float64
# Hobby                          object
# Country                        object
# StackOverflowJobsRecommend    float64
# VersionControl                 object
# Age                             int64
# Years Experience                int64
# Gender                         object
# RawSalary                      object
# dtype: object
#          SurveyDate                                    FormalEducation  \
# 0     2/28/18 20:20           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 1     6/28/18 13:26           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 2       6/6/18 3:37           Bachelor's degree (BA. BS. B.Eng.. etc.)
# 3       5/9/18 1:06  Some college/university study without earning ...
# 4     4/12/18 22:41           Bachelor's degree (BA. BS. B.Eng.. etc.)
# ..              ...                                                ...
# ...

# %%
### NULL VALUES IN COUNTRY
so_survey_df['Country'].isnull().values.any()
# Out:
# False

# %%
countries=so_survey_df['Country'].value_counts()
countries
# Out:
# South Africa    166
# USA             164
# Spain           134
# Sweeden         119
# France          115
# Russia           97
# India            95
# UK               95
# Ukraine           9
# Ireland           5
# Name: Country, dtype: int64

# %%
country=pd.DataFrame(so_survey_df['Country'].value_counts())

country.reset_index(inplace = True)
country
# Out:
#           index  Country
# 0  South Africa      166
# 1           USA      164
# 2         Spain      134
# 3       Sweeden      119
# 4        France      115
# 5        Russia       97
# 6         India       95
# 7            UK       95
# 8       Ukraine        9
# 9       Ireland        5

# %%
coo=pd.DataFrame(so_survey_df['Country'].value_counts()).reset_index(name='Count')
so_survey_df['Country'].value_counts().

country = so_survey_df['Country'].value_counts().reset_index(name='Count').rename(columns={'index':'Country'})
# Out:
#           index  Count
# 0  South Africa    166
# 1           USA    164
# 2         Spain    134
# 3       Sweeden    119
# 4        France    115
# 5        Russia     97
# 6         India     95
# 7            UK     95
# 8       Ukraine      9
# 9       Ireland      5

# %%
##################### FOLIUM #############

# %%
from geopandas.tools import geocode
from geopy.geocoders import Nominatim
import matplotlib
import folium

# %%
geolocator = Nominatim(user_agent="antonyjoy07@gmail.com")
location1=geolocator.geocode("World")
print((location1.latitude, location1.longitude))
print(location1.point)
# Out:
# (25.2528888, 55.17696777178696)
# 25 15m 10.3997s N, 55 10m 37.084s E

# %%
mapp=folium.Map((25.2528888, 55.17696777178696),zoom_start=2)



def locfind(location):
    
    location1=geolocator.geocode(location)
    return location1.latitude, location1.longitude,location1.address

for lab, row in country.iterrows() :
    
    x,y,z=locfind(row['index'])
    #folium.Circle(location=(x,y),icon=folium.Icon(icon_color='red'),popup=row['State']+":"+str(row['Active']),tooltip=row['State']).add_to(map)
    # folium.Marker(location=(row['Latitude'],row['Longitude']),icon=folium.Icon(icon_color='red'),popup=z).add_to(mapp)

    folium.CircleMarker(location=(x,y),radius=float(row['Country'])/5,popup=z,fill=True,color='crimson',fill_color='crimson',fill_opacity=.2).add_to(mapp)

    # Plotting 




mapp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# add marker one by one on the map
for i in range(0,len(data)):
   folium.Circle(
      location=[data.iloc[i]['lat'], data.iloc[i]['lon']],
      popup=data.iloc[i]['name'],
      radius=float(data.iloc[i]['value'])*20000,
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(m)

# Show the map again
