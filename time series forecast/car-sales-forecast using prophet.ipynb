# %%
https://www.youtube.com/watch?v=XZhPO043lqU&t=529s
import fbprophet
from fbprophet import Prophet
import pandas as pd
import numpy as np
from fbprophet.plot import add_changepoints_to_plot
from pandas import read_csv
from matplotlib import pyplot as plt
path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-car-sales.csv'
df = read_csv(path, header=0)
df
# Out:
#        Month  Sales
# 0    1960-01   6550
# 1    1960-02   8728
# 2    1960-03  12026
# 3    1960-04  14395
# 4    1960-05  14587
# ..       ...    ...
# 103  1968-08  16722
# 104  1968-09  14385
# 105  1968-10  21342
# 106  1968-11  17180
# 107  1968-12  14577
#
# [108 rows x 2 columns]

# %%
df.plot()
plt.show()

# %%
df.tail()
# Out:
#        Month  Sales
# 103  1968-08  16722
# 104  1968-09  14385
# 105  1968-10  21342
# 106  1968-11  17180
# 107  1968-12  14577

# %% [markdown]
# future= model.make_future_dataframe(periods=365)
#  Thus 365 days= forecast fro 365 dasy
#  https://mode.com/example-gallery/forecasting_prophet_python_cookbook/
#
#  https://www.digitalocean.com/community/tutorials/a-guide-to-time-series-forecasting-with-prophet-in-python-3
#
# https://mlcourse.ai/articles/topic9-part2-prophet/
#
# https://machinelearningmastery.com/time-series-forecasting-with-prophet-in-python/

# %%
df.columns=['ds','y']
model=Prophet()
model.fit(df)
future= model.make_future_dataframe(periods=365)
forecast=model.predict(future)
from fbprophet.plot import add_changepoints_to_plot
fig=model.plot(forecast)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
a=add_changepoints_to_plot(fig.gca(),model,forecast)

# %%
fig2 = model.plot_components(forecast)
plt.show()
forecast
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   1960-01-01   9600.274043   4618.131370   7767.618242   9600.274043
# 1   1960-02-01   9704.265356   5217.478296   8277.255248   9704.265356
# 2   1960-03-01   9801.547552  11181.646206  14204.251994   9801.547552
# 3   1960-04-01   9905.538865  13308.770179  16351.731792   9905.538865
# 4   1960-05-01  10006.175619  14561.634571  17654.228273  10006.175619
# ..         ...           ...           ...           ...           ...
# 468 1969-11-27  19053.148162  14873.123258  18000.972185  19019.508702
# 469 1969-11-28  19054.936098  15180.470850  18265.493502  19021.205984
# 470 1969-11-29  19056.724033  15013.147032  18324.796506  19022.903266
# 471 1969-11-30  19058.511969  15128.994144  18107.256930  19024.600548
# 472 1969-12-01  19060.299905  14812.158640  17953.021591  19026.197775
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
carsalefrom1969=forecast[138:472]
carsalefrom1969
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 138 1969-01-01  18463.129347  13761.807854  17043.754871  18463.002997
# 139 1969-01-02  18464.917283  14420.174661  17384.422848  18464.775373
# 140 1969-01-03  18466.705218  14585.394570  17717.097655  18466.543040
# 141 1969-01-04  18468.493154  14654.887211  17755.566592  18468.295898
# 142 1969-01-05  18470.281090  14723.900562  17799.910567  18470.065063
# ..         ...           ...           ...           ...           ...
# 467 1969-11-26  19051.360226  14404.021747  17588.905284  19017.822116
# 468 1969-11-27  19053.148162  14873.123258  18000.972185  19019.508702
# 469 1969-11-28  19054.936098  15180.470850  18265.493502  19021.205984
# 470 1969-11-29  19056.724033  15013.147032  18324.796506  19022.903266
# 471 1969-11-30  19058.511969  15128.994144  18107.256930  19024.600548
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
carsalefrom1969['ds'] = carsalefrom1969['ds'].astype(str)
carsalefrom1969
# Out:
# <ipython-input-8-1523e396c792>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carsalefrom1969['ds'] = carsalefrom1969['ds'].astype(str)
#              ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 138  1969-01-01  18463.129347  13761.807854  17043.754871  18463.002997
# 139  1969-01-02  18464.917283  14420.174661  17384.422848  18464.775373
# 140  1969-01-03  18466.705218  14585.394570  17717.097655  18466.543040
# 141  1969-01-04  18468.493154  14654.887211  17755.566592  18468.295898
# 142  1969-01-05  18470.281090  14723.900562  17799.910567  18470.065063
# ..          ...           ...           ...           ...           ...
# 467  1969-11-26  19051.360226  14404.021747  17588.905284  19017.822116
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-7b0c2cba9ae5> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
carsalefrom1969.to_csv('carsalefrom1969.csv')
# !cp carsalefrom1969.csv "drive/My Drive/"
