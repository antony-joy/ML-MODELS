# %%
#The capital_onebike.csv file covers the October, November and December rides of the Capital Bikeshare bike W20529.

import pandas as pd
address="C:/Users/ANTHONY/Desktop/CSV&XLSX/capital_onebike.csv"

rides = pd.read_csv(address,parse_dates = ['Start date', 'End date'])   #####3else it will read dates as just string objects
rides
# Out:
#              Start date            End date  Start station number  \
# 0   2017-10-01 15:23:25 2017-10-01 15:26:26                 31038
# 1   2017-10-01 15:42:57 2017-10-01 17:49:59                 31036
# 2   2017-10-02 06:37:10 2017-10-02 06:42:53                 31036
# 3   2017-10-02 08:56:45 2017-10-02 09:18:03                 31037
# 4   2017-10-02 18:23:48 2017-10-02 18:45:05                 31295
# ..                  ...                 ...                   ...
# 285 2017-12-29 14:32:55 2017-12-29 14:43:46                 31242
# 286 2017-12-29 15:08:26 2017-12-29 15:18:51                 31265
# 287 2017-12-29 20:33:34 2017-12-29 20:38:13                 31613
# 288 2017-12-30 13:51:03 2017-12-30 13:54:33                 31618
# 289 2017-12-30 15:09:03 2017-12-30 15:19:13                 31610
#
#                                          Start station  End station number  \
# 0                                 Glebe Rd & 11th St N               31036
# 1                        George Mason Dr & Wilson Blvd               31036
# 2                        George Mason Dr & Wilson Blvd               31037
# 3                 Ballston Metro / N Stuart & 9th St N               31295
# 4                                    Potomac & M St NW               31230
# ..                                                 ...                 ...
# 285                      18th St & Pennsylvania Ave NW               31265
# 286                      5th St & Massachusetts Ave NW               31613
# 287  Eastern Market Metro / Pennsylvania Ave & 7th ...               31618
# 288                           4th & East Capitol St NE               31610
# 289       Eastern Market / 7th & North Carolina Ave SE               31272
#
#                                            End station Bike number Member type
# 0                        George Mason Dr & Wilson Blvd      W20529      Member
# 1                        George Mason Dr & Wilson Blvd      W20529      Casual
# 2                 Ballston Metro / N Stuart & 9th St N      W20529      Member
# 3                                    Potomac & M St NW      W20529      Member
# 4                        Metro Center / 12th & G St NW      W20529      Member
# ..                                                 ...         ...         ...
# 285                      5th St & Massachusetts Ave NW      W20529      Member
# 286  Eastern Market Metro / Pennsylvania Ave & 7th ...      W20529      Casual
# 287                           4th & East Capitol St NE      W20529      Member
# 288       Eastern Market / 7th & North Carolina Ave SE      W20529      Member
# 289               Washington & Independence Ave SW/HHS      W20529      Member
#
# [290 rows x 8 columns]

# %%
len(rides) , rides.size
# Out:
# (290, 2320)

# %%
rides.dtypes
# Out:
# Start date              datetime64[ns]
# End date                datetime64[ns]
# Start station number             int64
# Start station                   object
# End station number               int64
# End station                     object
# Bike number                     object
# Member type                     object
# dtype: object

# %%
############# TO KNOW THE TIMING OF RIDES FOR EACH RIDE[WHICH ARE EACH ROW]  ############

# Subtract the start date from the end date
ride_durations = rides['End date'] - rides['Start date']


# Convert the results to seconds
rides['Duration'] = ride_durations.dt.total_seconds()
rides
# Out:
#              Start date            End date  Start station number  \
# 0   2017-10-01 15:23:25 2017-10-01 15:26:26                 31038
# 1   2017-10-01 15:42:57 2017-10-01 17:49:59                 31036
# 2   2017-10-02 06:37:10 2017-10-02 06:42:53                 31036
# 3   2017-10-02 08:56:45 2017-10-02 09:18:03                 31037
# 4   2017-10-02 18:23:48 2017-10-02 18:45:05                 31295
# ..                  ...                 ...                   ...
# 285 2017-12-29 14:32:55 2017-12-29 14:43:46                 31242
# 286 2017-12-29 15:08:26 2017-12-29 15:18:51                 31265
# 287 2017-12-29 20:33:34 2017-12-29 20:38:13                 31613
# 288 2017-12-30 13:51:03 2017-12-30 13:54:33                 31618
# 289 2017-12-30 15:09:03 2017-12-30 15:19:13                 31610
#
#                                          Start station  End station number  \
# 0                                 Glebe Rd & 11th St N               31036
# 1                        George Mason Dr & Wilson Blvd               31036
# 2                        George Mason Dr & Wilson Blvd               31037
# 3                 Ballston Metro / N Stuart & 9th St N               31295
# 4                                    Potomac & M St NW               31230
# ..                                                 ...                 ...
# 285                      18th St & Pennsylvania Ave NW               31265
# 286                      5th St & Massachusetts Ave NW               31613
# 287  Eastern Market Metro / Pennsylvania Ave & 7th ...               31618
# 288                           4th & East Capitol St NE               31610
# 289       Eastern Market / 7th & North Carolina Ave SE               31272
#
#                                            End station Bike number  \
# 0                        George Mason Dr & Wilson Blvd      W20529
# 1                        George Mason Dr & Wilson Blvd      W20529
# 2                 Ballston Metro / N Stuart & 9th St N      W20529
# 3                                    Potomac & M St NW      W20529
# 4                        Metro Center / 12th & G St NW      W20529
# ..                                                 ...         ...
# 285                      5th St & Massachusetts Ave NW      W20529
# 286  Eastern Market Metro / Pennsylvania Ave & 7th ...      W20529
# 287                           4th & East Capitol St NE      W20529
# 288       Eastern Market / 7th & North Carolina Ave SE      W20529
# 289               Washington & Independence Ave SW/HHS      W20529
#
#     Member type  Duration
# 0        Member     181.0
# 1        Casual    7622.0
# 2        Member     343.0
# 3        Member    1278.0
# 4        Member    1277.0
# ..          ...       ...
# 285      Member     651.0
# 286      Casual     625.0
# 287      Member     279.0
# 288      Member     210.0
# 289      Member     610.0
#
# [290 rows x 9 columns]

# %%
############# TO KNOW THE TIMING OF RIDES in minutes FOR EACH RIDE[WHICH ARE EACH ROW]  ############

# Subtract the start date from the end date
ride_durations = rides['End date'] - rides['Start date']

# Convert the results to seconds
rides['Duration in minutes'] = [divmod(i, 60)[0] for i in rides.Duration]
rides
# Out:
#              Start date            End date  Start station number  \
# 0   2017-10-01 15:23:25 2017-10-01 15:26:26                 31038
# 1   2017-10-01 15:42:57 2017-10-01 17:49:59                 31036
# 2   2017-10-02 06:37:10 2017-10-02 06:42:53                 31036
# 3   2017-10-02 08:56:45 2017-10-02 09:18:03                 31037
# 4   2017-10-02 18:23:48 2017-10-02 18:45:05                 31295
# ..                  ...                 ...                   ...
# 285 2017-12-29 14:32:55 2017-12-29 14:43:46                 31242
# 286 2017-12-29 15:08:26 2017-12-29 15:18:51                 31265
# 287 2017-12-29 20:33:34 2017-12-29 20:38:13                 31613
# 288 2017-12-30 13:51:03 2017-12-30 13:54:33                 31618
# 289 2017-12-30 15:09:03 2017-12-30 15:19:13                 31610
#
#                                          Start station  End station number  \
# 0                                 Glebe Rd & 11th St N               31036
# 1                        George Mason Dr & Wilson Blvd               31036
# 2                        George Mason Dr & Wilson Blvd               31037
# 3                 Ballston Metro / N Stuart & 9th St N               31295
# 4                                    Potomac & M St NW               31230
# ..                                                 ...                 ...
# 285                      18th St & Pennsylvania Ave NW               31265
# 286                      5th St & Massachusetts Ave NW               31613
# 287  Eastern Market Metro / Pennsylvania Ave & 7th ...               31618
# 288                           4th & East Capitol St NE               31610
# 289       Eastern Market / 7th & North Carolina Ave SE               31272
#
#                                            End station Bike number  \
# 0                        George Mason Dr & Wilson Blvd      W20529
# 1                        George Mason Dr & Wilson Blvd      W20529
# 2                 Ballston Metro / N Stuart & 9th St N      W20529
# 3                                    Potomac & M St NW      W20529
# 4                        Metro Center / 12th & G St NW      W20529
# ..                                                 ...         ...
# 285                      5th St & Massachusetts Ave NW      W20529
# 286  Eastern Market Metro / Pennsylvania Ave & 7th ...      W20529
# 287                           4th & East Capitol St NE      W20529
# 288       Eastern Market / 7th & North Carolina Ave SE      W20529
# 289               Washington & Independence Ave SW/HHS      W20529
#
#     Member type  Duration  Duration in minutes
# 0        Member     181.0                  3.0
# 1        Casual    7622.0                127.0
# 2        Member     343.0                  5.0
# 3        Member    1278.0                 21.0
# 4        Member    1277.0                 21.0
# ..          ...       ...                  ...
# 285      Member     651.0                 10.0
# 286      Casual     625.0                 10.0
# 287      Member     279.0                  4.0
# 288      Member     210.0                  3.0
# 289      Member     610.0                 10.0
#
# [290 rows x 10 columns]

# %% [markdown]
# #### How many joyrides?
# Suppose you have a theory that some people take long bike rides before putting their bike back in the same dock. Let's call these rides "joyrides".

# %%
rides[rides['Start station']==rides['End station']]   ################      it shows 6 rows         ############
# Out:
#              Start date            End date  Start station number  \
# 1   2017-10-01 15:42:57 2017-10-01 17:49:59                 31036
# 31  2017-10-06 15:50:10 2017-10-06 16:12:34                 31129
# 99  2017-10-23 17:13:16 2017-10-23 19:31:26                 31258
# 180 2017-11-20 22:39:48 2017-11-20 23:23:37                 31259
# 218 2017-12-03 17:20:17 2017-12-03 18:04:33                 31265
# 280 2017-12-25 13:46:44 2017-12-25 14:20:50                 31247
#
#                                    Start station  End station number  \
# 1                  George Mason Dr & Wilson Blvd               31036
# 31   15th St & Pennsylvania Ave NW/Pershing Park               31129
# 99                              Lincoln Memorial               31258
# 180                    20th St & Virginia Ave NW               31259
# 218                5th St & Massachusetts Ave NW               31265
# 280                    Jefferson Dr & 14th St SW               31247
#
#                                      End station Bike number Member type  \
# 1                  George Mason Dr & Wilson Blvd      W20529      Casual
# 31   15th St & Pennsylvania Ave NW/Pershing Park      W20529      Casual
# 99                              Lincoln Memorial      W20529      Casual
# 180                    20th St & Virginia Ave NW      W20529      Casual
# 218                5th St & Massachusetts Ave NW      W20529      Casual
# 280                    Jefferson Dr & 14th St SW      W20529      Casual
#
#      Duration  Duration in minutes
# 1      7622.0                127.0
# 31     1344.0                 22.0
# 99     8290.0                138.0
# 180    2629.0                 43.0
# 218    2656.0                 44.0
# 280    2046.0                 34.0

# %%
rides[rides['Start station']==rides['End station']].count()
# Out:
# Start date              6
# End date                6
# Start station number    6
# Start station           6
# End station number      6
# End station             6
# Bike number             6
# Member type             6
# Duration                6
# Duration in minutes     6
# dtype: int64

# %%
# Create joyrides
joyrides = (rides['Start station'] == rides['End station'])

# Total number of joyrides
print("{} rides were joyrides".format(joyrides.sum()))
# Out:
# 6 rides were joyrides

# %%
##################################  OR  ###########################
(rides['Start station'] == rides['End station']).sum()
# Out:
# 6

# %% [markdown]
# #### How might the weather or the season have affected the length of bike trips?

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Resample rides to daily, take the size, plot the results            ######### D- daily, W= weekly , M= monthly
rides.resample('D', on = 'Start date').size().plot()                  ######### size = number of rows * columns

# Show the results
plt.show()

# %%
rides['day']= rides['Start date'].dt.day
rides
# Out:
#              Start date            End date  Start station number  \
# 0   2017-10-01 15:23:25 2017-10-01 15:26:26                 31038
# 1   2017-10-01 15:42:57 2017-10-01 17:49:59                 31036
# 2   2017-10-02 06:37:10 2017-10-02 06:42:53                 31036
# 3   2017-10-02 08:56:45 2017-10-02 09:18:03                 31037
# 4   2017-10-02 18:23:48 2017-10-02 18:45:05                 31295
# ..                  ...                 ...                   ...
# 285 2017-12-29 14:32:55 2017-12-29 14:43:46                 31242
# 286 2017-12-29 15:08:26 2017-12-29 15:18:51                 31265
# 287 2017-12-29 20:33:34 2017-12-29 20:38:13                 31613
# 288 2017-12-30 13:51:03 2017-12-30 13:54:33                 31618
# 289 2017-12-30 15:09:03 2017-12-30 15:19:13                 31610
#
#                                          Start station  End station number  \
# 0                                 Glebe Rd & 11th St N               31036
# 1                        George Mason Dr & Wilson Blvd               31036
# 2                        George Mason Dr & Wilson Blvd               31037
# 3                 Ballston Metro / N Stuart & 9th St N               31295
# 4                                    Potomac & M St NW               31230
# ..                                                 ...                 ...
# 285                      18th St & Pennsylvania Ave NW               31265
# 286                      5th St & Massachusetts Ave NW               31613
# 287  Eastern Market Metro / Pennsylvania Ave & 7th ...               31618
# 288                           4th & East Capitol St NE               31610
# 289       Eastern Market / 7th & North Carolina Ave SE               31272
#
#                                            End station Bike number  \
# 0                        George Mason Dr & Wilson Blvd      W20529
# 1                        George Mason Dr & Wilson Blvd      W20529
# 2                 Ballston Metro / N Stuart & 9th St N      W20529
# 3                                    Potomac & M St NW      W20529
# 4                        Metro Center / 12th & G St NW      W20529
# ..                                                 ...         ...
# 285                      5th St & Massachusetts Ave NW      W20529
# 286  Eastern Market Metro / Pennsylvania Ave & 7th ...      W20529
# 287                           4th & East Capitol St NE      W20529
# 288       Eastern Market / 7th & North Carolina Ave SE      W20529
# 289               Washington & Independence Ave SW/HHS      W20529
#
#     Member type  Duration  Duration in minutes  day
# 0        Member     181.0                  3.0    1
# 1        Casual    7622.0                127.0    1
# 2        Member     343.0                  5.0    2
# 3        Member    1278.0                 21.0    2
# 4        Member    1277.0                 21.0    2
# ..          ...       ...                  ...  ...
# 285      Member     651.0                 10.0   29
# 286      Casual     625.0                 10.0   29
# 287      Member     279.0                  4.0   29
# 288      Member     210.0                  3.0   30
# 289      Member     610.0                 10.0   30
#
# [290 rows x 11 columns]

# %%
############   wont work for time series ##############
plt.plot(rides['day'])

# %% [markdown]
# ### Members vs casual riders over time

# %%
rides.groupby('Member type').count()
# Out:
#              Start date  End date  Start station number  Start station  \
# Member type
# Casual               54        54                    54             54
# Member              236       236                   236            236
#
#              End station number  End station  Bike number  Duration  \
# Member type
# Casual                       54           54           54        54
# Member                      236          236          236       236
#
#              Duration in minutes  day
# Member type
# Casual                        54   54
# Member                       236  236

# %%
rides['Member type'].value_counts()
# Out:
# Member    236
# Casual     54
# Name: Member type, dtype: int64

# %%
#################################################           OVER TIME             #########################################


#########    RESAMPLE

# Resample rides to be monthly on the basis of Start date
monthly_rides = rides.resample('M', on = 'Start date')['Member type']
print(monthly_rides.value_counts())

print(monthly_rides.size())
# Out:
# Start date  Member type
# 2017-10-31  Member         83
#             Casual         25
# 2017-11-30  Member         85
#             Casual         18
# 2017-12-31  Member         68
#             Casual         11
# Name: Member type, dtype: int64
# Start date
# 2017-10-31    108
# 2017-11-30    103
# 2017-12-31     79
# Freq: M, Name: Member type, dtype: int64

# %%
#########    GROUP BY
rides.groupby(['Member type', 'month'])["Duration"].count()
# Out:
# Member type  month
# Casual       10       25
#              11       18
#              12       11
# Member       10       83
#              11       85
#              12       68
# Name: Duration, dtype: int64

# %%
###########  PIVOT TABLE
import numpy as np
pd.pivot_table(rides,index=['Member type', 'month'],values=["Duration"],aggfunc='count')
# Out:
#                    Duration
# Member type month
# Casual      10           25
#             11           18
#             12           11
# Member      10           83
#             11           85
#             12           68

# %%
df1.pivot_table(columns="Name",values="Chats",aggfunc='count')

# %%
df1.pivot_table(columns=['Member type', 'month'],values="Duration",aggfunc='count')

# %%
#########    RESAMPLE


# Group rides by member type, and resample to the month
grouped = rides.groupby('Member type').resample('M', on = 'Start date')

# Print the median duration for each group
print(grouped['Duration'].median())
# Out:
# Member type  Start date
# Casual       2017-10-31    1636.0
#              2017-11-30    1159.5
#              2017-12-31     850.0
# Member       2017-10-31     671.0
#              2017-11-30     655.0
#              2017-12-31     387.5
# Name: Duration, dtype: float64

# %%
#########    GROUP BY


rides.groupby(['Member type', 'month'])["Duration"].median()
# Out:
# Member type  month
# Casual       10       1636.0
#              11       1159.5
#              12        850.0
# Member       10        671.0
#              11        655.0
#              12        387.5
# Name: Duration, dtype: float64

# %%
# Take the ratio of the .value_counts() over the total number of rides
print(monthly_rides.value_counts() / monthly_rides.size())                       #size is rows*columns
# Out:
# Start date  Member type
# 2017-10-31  Member         0.768519
#             Casual         0.231481
# 2017-11-30  Member         0.825243
#             Casual         0.174757
# 2017-12-31  Member         0.860759
#             Casual         0.139241
# Name: Member type, dtype: float64

# %%
##################### ANOTHER METHOD ::: MAKING SEPERATE DF COLUMN BASED ON MONTH  AND VALUE COUNTS ##############


rides['month']= rides['Start date'].dt.month
rides
# Out:
#              Start date            End date  Start station number  \
# 0   2017-10-01 15:23:25 2017-10-01 15:26:26                 31038
# 1   2017-10-01 15:42:57 2017-10-01 17:49:59                 31036
# 2   2017-10-02 06:37:10 2017-10-02 06:42:53                 31036
# 3   2017-10-02 08:56:45 2017-10-02 09:18:03                 31037
# 4   2017-10-02 18:23:48 2017-10-02 18:45:05                 31295
# ..                  ...                 ...                   ...
# 285 2017-12-29 14:32:55 2017-12-29 14:43:46                 31242
# 286 2017-12-29 15:08:26 2017-12-29 15:18:51                 31265
# 287 2017-12-29 20:33:34 2017-12-29 20:38:13                 31613
# 288 2017-12-30 13:51:03 2017-12-30 13:54:33                 31618
# 289 2017-12-30 15:09:03 2017-12-30 15:19:13                 31610
#
#                                          Start station  End station number  \
# 0                                 Glebe Rd & 11th St N               31036
# 1                        George Mason Dr & Wilson Blvd               31036
# 2                        George Mason Dr & Wilson Blvd               31037
# 3                 Ballston Metro / N Stuart & 9th St N               31295
# 4                                    Potomac & M St NW               31230
# ..                                                 ...                 ...
# 285                      18th St & Pennsylvania Ave NW               31265
# 286                      5th St & Massachusetts Ave NW               31613
# 287  Eastern Market Metro / Pennsylvania Ave & 7th ...               31618
# 288                           4th & East Capitol St NE               31610
# 289       Eastern Market / 7th & North Carolina Ave SE               31272
#
#                                            End station Bike number  \
# 0                        George Mason Dr & Wilson Blvd      W20529
# 1                        George Mason Dr & Wilson Blvd      W20529
# 2                 Ballston Metro / N Stuart & 9th St N      W20529
# 3                                    Potomac & M St NW      W20529
# 4                        Metro Center / 12th & G St NW      W20529
# ..                                                 ...         ...
# 285                      5th St & Massachusetts Ave NW      W20529
# 286  Eastern Market Metro / Pennsylvania Ave & 7th ...      W20529
# 287                           4th & East Capitol St NE      W20529
# 288       Eastern Market / 7th & North Carolina Ave SE      W20529
# 289               Washington & Independence Ave SW/HHS      W20529
#
#     Member type  Duration  Duration in minutes  day  month
# 0        Member     181.0                  3.0    1     10
# 1        Casual    7622.0                127.0    1     10
# 2        Member     343.0                  5.0    2     10
# 3        Member    1278.0                 21.0    2     10
# 4        Member    1277.0                 21.0    2     10
# ..          ...       ...                  ...  ...    ...
# 285      Member     651.0                 10.0   29     12
# 286      Casual     625.0                 10.0   29     12
# 287      Member     279.0                  4.0   29     12
# 288      Member     210.0                  3.0   30     12
# 289      Member     610.0                 10.0   30     12
#
# [290 rows x 12 columns]

# %%
############################################   THIS IS SAME AS ABOVE RESAMPLING   #####################################
############################################                                      #####################################

dfcross=pd.crosstab(rides['Member type'],rides.month)               #######can have only 2 columns
dfcross
# Out:
# month        10  11  12
# Member type
# Casual       25  18  11
# Member       83  85  68

# %% [markdown]
# ### Timezones in Pandas

# %%
# Localize the Start date column to America/New_York
rides['Start date'] = rides['Start date'].dt.tz_localize('America/New_York',  ambiguous='NaT')

# Print first value
print(rides['Start date'].iloc[0])

# Convert the Start date column to Europe/London
rides['Start date'] = rides['Start date'].dt.tz_convert('Europe/London')


# Print the new value
print(rides['Start date'].iloc[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-3de6f2e36703> in <module>
#       1 # Localize the Start date column to America/New_York
# ----> 2 rides['Start date'] = rides['Start date'].dt.tz_localize('America/New_York',  ambiguous='NaT')
#       3
#       4 # Print first value
#       5 print(rides['Start date'].iloc[0])
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in f(self, *args, **kwargs)
#      97         def _create_delegator_method(name):
#      98             def f(self, *args, **kwargs):
# ---> 99                 return self._delegate_method(name, *args, **kwargs)
#     100
#     101             f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in _delegate_method(self, name, *args, **kwargs)
#     102
#     103         method = getattr(values, name)
# --> 104         result = method(*args, **kwargs)
#     105
#     106         if not is_list_like(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in tz_localize(self, tz, ambiguous, nonexistent)
#     233         self, tz, ambiguous="raise", nonexistent="raise"
#     234     ) -> "DatetimeIndex":
# --> 235         arr = self._data.tz_localize(tz, ambiguous, nonexistent)
#     236         return type(self)._simple_new(arr, name=self.name)
#     237
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in tz_localize(self, tz, ambiguous, nonexistent)
#     963                 new_dates = tzconversion.tz_convert_from_utc(self.asi8, self.tz)
#     964             else:
# --> 965                 raise TypeError("Already tz-aware, use tz_convert to convert.")
#     966         else:
#     967             tz = timezones.maybe_get_tz(tz)
#
# TypeError: Already tz-aware, use tz_convert to convert.

# %% [markdown]
# ### How long per weekday?

# %%
# Add a column for the weekday of the start of the ride
rides['Ride start weekday'] = rides['Start date'].dt.day_name()

# Print the median trip time per weekday
rides.groupby('Ride start weekday')['Duration'].median()
# Out:
# Ride start weekday
# Friday       684.0
# Monday       922.5
# Saturday     610.0
# Sunday       625.0
# Thursday     659.0
# Tuesday      644.0
# Wednesday    629.0
# Name: Duration, dtype: float64

# %% [markdown]
# ### How long between rides? grouped by months?

# %%
# Shift the index of the end date up one; now subract it from the start date
rides['Time since'] = rides['Start date'] - (rides['End date'].shift(1))

# Move from a timedelta to a number of seconds, which is easier to work with
rides['Time since'] = rides['Time since'].dt.total_seconds()

# Resample to the month
monthly = rides.resample('M', on = 'Start date')

# Print the average hours between rides each month
print(monthly['Time since'].mean()/(60*60))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-838b415959aa> in <module>
#       1 # Shift the index of the end date up one; now subract it from the start date
# ----> 2 rides['Time since'] = rides['Start date'] - (rides['End date'].shift(1))
#       3
#       4 # Move from a timedelta to a number of seconds, which is easier to work with
#       5 rides['Time since'] = rides['Time since'].dt.total_seconds()
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     184     if should_extension_dispatch(lvalues, rvalues) or isinstance(rvalues, Timedelta):
#     185         # Timedelta is included because numexpr will fail on it, see GH#31457
# --> 186         res_values = op(lvalues, rvalues)
#     187
#     188     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in __sub__(self, other)
#    1480         elif is_datetime64_dtype(other_dtype) or is_datetime64tz_dtype(other_dtype):
#    1481             # DatetimeIndex, ndarray[datetime64]
# -> 1482             result = self._sub_datetime_arraylike(other)
#    1483         elif is_period_dtype(other_dtype):
#    1484             # PeriodIndex
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in _sub_datetime_arraylike(self, other)
#     661         if not self._has_same_tz(other):
#     662             # require tz compat
# --> 663             raise TypeError(
#     664                 f"{type(self).__name__} subtraction must have the same "
#     665                 "timezones or no timezones"
#
# TypeError: DatetimeArray subtraction must have the same timezones or no timezones

# %%
rides.groupby('month')['Duration in minutes'].mean()
# Out:
# month
# 10    30.953704
# 11    13.757282
# 12    10.101266
# Name: Duration in minutes, dtype: float64

# %% [markdown]
# https://stackoverflow.com/questions/1345827/how-do-i-find-the-time-difference-between-two-datetime-objects-in-python

# %% [markdown]
# https://medium.com/open-machine-learning-course/open-machine-learning-course-topic-1-exploratory-data-analysis-with-pandas-de57880f1a68
