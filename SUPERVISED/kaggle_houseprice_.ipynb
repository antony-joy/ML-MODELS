# %% [markdown]
# ### DATA ACQUISITION

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

import pandas as pd


pd.pandas.set_option('display.max_columns',None)
########## using pandas
df_train= pd.read_csv("C:/Users/ANTHONY/Desktop/CSV&XLSX/houseprice/train.csv")
#df_trn
df_test= pd.read_csv("C:/Users/ANTHONY/Desktop/CSV&XLSX/houseprice/test.csv")

df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### DATA PREPROCESSING

# %%
########   DATATYPES OF COLUMNS

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#######   MISSING VALUES

print(df_train.isnull().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
import seaborn as sns

#######  

sns.heatmap(df_train.isnull(),yticklabels=False,cbar=False).set(title='HEAT MAP REPRESENTATION OF NULL VALUES')
# Out:
# [Text(0.5, 1.0, 'HEAT MAP REPRESENTATION OF NULL VALUES')]

# %%
###########33  null coloumns in train set-- 19

df_train.columns[df_train.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
###########33  null coloumns in test set-- 33


df_test.columns[df_test.isnull().any()]
# Out:
# Index(['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType'],
#       dtype='object')

# %%
######  cols have NA values which area actually not NA


########  IMPUTATION
cols=["Alley","BsmtQual","BsmtExposure","BsmtFinType1","BsmtFinType2","BsmtCond","FireplaceQu","GarageType","GarageFinish","GarageQual","GarageCond","PoolQC","Fence","MiscFeature"]

df_train[cols]=df_train[cols].fillna("NotPresent")

import seaborn as sns

#######  

sns.heatmap(df_train.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street       Alley  \
# 0        1          60       RL         65.0     8450   Pave  NotPresent
# 1        2          20       RL         80.0     9600   Pave  NotPresent
# 2        3          60       RL         68.0    11250   Pave  NotPresent
# 3        4          70       RL         60.0     9550   Pave  NotPresent
# 4        5          60       RL         84.0    14260   Pave  NotPresent
# ...    ...         ...      ...          ...      ...    ...         ...
# 1455  1456          60       RL         62.0     7917   Pave  NotPresent
# 1456  1457          20       RL         85.0    13175   Pave  NotPresent
# 1457  1458          70       RL         66.0     9042   Pave  NotPresent
# 1458  1459          20       RL         68.0     9717   Pave  NotPresent
# 1459  1460          20       RL         75.0     9937   Pave  NotPresent
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
df_train.columns[df_train.isnull().any()]
# Out:
# Index(['LotFrontage', 'MasVnrType', 'MasVnrArea', 'Electrical', 'GarageYrBlt'], dtype='object')

# %%
####3  convert object into category

df_train.loc[:, df_train.dtypes == 'object'] =\
    df_train.select_dtypes(['object'])\
    .apply(lambda x: x.astype('category'))

#df_train.select_dtypes(['object']).apply(lambda x: x.astype('category'))

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   category
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   category
#  6   Alley          1460 non-null   category
#  7   LotShape       1460 non-null   category
#  8   LandContour    1460 non-null   category
#  9   Utilities      1460 non-null   category
#  10  LotConfig      1460 non-null   category
#  11  LandSlope      1460 non-null   category
#  12  Neighborhood   1460 non-null   category
#  13  Condition1     1460 non-null   category
#  14  Condition2     1460 non-null   category
#  15  BldgType       1460 non-null   category
#  16  HouseStyle     1460 non-null   category
# ...

# %%
# GarageYrBlt,Electrical,MasVnrType,MasVnrArea,LotFrontage
df_train[["GarageYrBlt","Electrical","MasVnrType","MasVnrArea","LotFrontage"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GarageYrBlt  1379 non-null   float64
#  1   Electrical   1459 non-null   category
#  2   MasVnrType   1452 non-null   category
#  3   MasVnrArea   1452 non-null   float64
#  4   LotFrontage  1201 non-null   float64
# dtypes: category(2), float64(3)
# memory usage: 37.6 KB

# %%
########  IMPUTATION

cat_cols = df_train.select_dtypes(include=['category']).columns
num_cols = df_train.select_dtypes(include=['number']).columns


for i in num_cols:
    df_train[i].fillna(value=df_train[i].mean(), inplace=True)
for i in cat_cols:
    df_train[i].fillna(value=df_train[i].mode()[0], inplace=True)

# %%
sns.heatmap(df_train.isnull(),yticklabels=False,cbar=False).set(title='HEAT MAP REPRESENTATION AFTER IMPUTATION')
# Out:
# [Text(0.5, 1.0, 'HEAT MAP REPRESENTATION AFTER IMPUTATION')]

# %%
######33  DUPLICATE

duplicate = df_train[df_train.duplicated()]
  
print("Duplicate Rows :")
  
# Print the resultant Dataframe
duplicate   ######no duplicate rows
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
sns.heatmap(df_test.isnull(),yticklabels=False,cbar=False).set(title='HEAT MAP of test set REPRESENTATION BEFORE IMPUTATION')
# Out:
# [Text(0.5, 1.0, 'HEAT MAP of test set REPRESENTATION BEFORE IMPUTATION')]

# %%
###############   TEST SET DOING SAME THINGS

######  cols have NA values which area actually not NA

cols=["Alley","BsmtQual","BsmtExposure","BsmtFinType1","BsmtFinType2","BsmtCond","FireplaceQu","GarageType","GarageFinish","GarageQual","GarageCond","PoolQC","Fence","MiscFeature"]

df_test[cols]=df_test[cols].fillna("NotPresent")
#####  doing all these steps in df_test

####3  convert object into category

df_test.loc[:, df_test.dtypes == 'object'] =\
    df_test.select_dtypes(['object'])\
    .apply(lambda x: x.astype('category'))

#df_train.select_dtypes(['object']).apply(lambda x: x.astype('category'))
#df_test["GarageYrBlt"].fillna(df_test["YearBuilt"], inplace=True)
#data["GarageYrBlt"]=data['YearBuilt']-data["GarageYrBlt"]

cat_cols = df_test.select_dtypes(include=['category']).columns
num_cols = df_test.select_dtypes(include=['number']).columns

for i in num_cols:
    df_test[i].fillna(value=df_train[i].mean(), inplace=True)
for i in cat_cols:
    df_test[i].fillna(value=df_train[i].mode()[0], inplace=True)
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   category
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   category
#  6   Alley          1459 non-null   category
#  7   LotShape       1459 non-null   category
#  8   LandContour    1459 non-null   category
#  9   Utilities      1459 non-null   category
#  10  LotConfig      1459 non-null   category
#  11  LandSlope      1459 non-null   category
#  12  Neighborhood   1459 non-null   category
#  13  Condition1     1459 non-null   category
#  14  Condition2     1459 non-null   category
#  15  BldgType       1459 non-null   category
#  16  HouseStyle     1459 non-null   category
# ...

# %%
sns.heatmap(df_test.isnull(),yticklabels=False,cbar=False).set(title='HEAT MAP of test set REPRESENTATION after IMPUTATION')
# Out:
# [Text(0.5, 1.0, 'HEAT MAP of test set REPRESENTATION after IMPUTATION')]

# %% [markdown]
# ### EDA AND FEATURE ENGINEEERING

# %%
######  looking for temporal fatures

year_feature=['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
df_train.groupby('YrSold')['SalePrice'].mean().plot()
plt.xlabel('Year Sold')
plt.ylabel('Mean Sold House Price')
plt.title("Sale Price vs YearSold")

#######  yearsold does not give a clear idea of data, as usually with being sold in latest years price should go up, but it shows price is going down
# Out:
# Text(0.5, 1.0, 'Sale Price vs YearSold')

# %%
for feature in year_feature:
    if feature!='YrSold':
        data=df_train.copy()
        ## We will capture the difference between year variable and year the house was sold for
        data[feature]=data['YrSold']-data[feature]
        plt.scatter(data[feature],data['SalePrice'],color='red')
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

df_train["GarageYrBlt"]=df_train["GarageYrBlt"]-df_train['YearBuilt']

# %%
df_train["GarageYrBlt"].value_counts()
# Out:
#  0.000000      1089
#  1.000000        52
#  2.000000        16
#  3.000000        10
#  4.000000         7
#  8.000000         7
#  14.000000        6
#  20.000000        6
#  40.000000        6
#  50.000000        6
#  17.000000        5
#  37.000000        5
#  68.506164        5
#  58.506164        5
#  12.000000        5
#  7.000000         5
#  18.000000        5
#  6.000000         5
#  45.000000        5
#  77.000000        4
#  64.506164        4
#  47.000000        4
#  27.000000        4
#  46.000000        4
#  5.000000         4
#  38.506164        4
#  7.506164         4
#  10.000000        4
#  15.000000        4
#  33.000000        3
#  43.000000        3
#  22.000000        3
#  70.000000        3
#  41.000000        3
#  21.000000        3
#  13.000000        3
#  56.506164        3
#  8.506164         3
#  35.000000        3
#  9.000000         3
#  62.000000        3
#  53.000000        3
#  56.000000        3
#  69.000000        3
#  36.000000        3
# ...

# %%
########  GarageYrBlt and YearBuilt gives same information as only few rows[almost 10] have difference as most garages were built along with house or a difference of 1-3 year gap

# %%
#####  FINDING ALL UNIQUE ROWS IN DF_TRAIN
cat_cols = df_train.select_dtypes(include=['category']).columns


for i in cat_cols:
    print(i)
    print(df_train["%s"%i].value_counts())
    print("\n")
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
#
#
# Street
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64
#
#
# Alley
# NotPresent    1369
# Grvl            50
# Pave            41
# Name: Alley, dtype: int64
#
#
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
#
#
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
#
#
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64
#
#
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
#
#
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
#
#
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# ...

# %%
######  Street, Utilities  have very less uniqueness
### removing street,utilities



y=df_train["SalePrice"]

#######33  ID  removed as its unnecessary

#######  also removing garageyearbuilt as its unncessary

df_train=df_train.drop(["Id","Street","Utilities","GarageYrBlt"],axis=1)
df_test=df_test.drop(["Id","Street","Utilities","GarageYrBlt"],axis=1)
df_train.shape,df_test.shape
# Out:
# ((1460, 77), (1459, 76))

# %%
#######  REMOVING LEAST CORRELATED


#df_train.shape
#####  finding out features that are less correlated and then removing them

#df_train["SalePrice"]=y

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30, 30))

sns.heatmap(df_train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
## least correlated to saleprice is "BsmtFinSF2","LowQualFinSF","BsmtHalfBath", 'MiscVal', 'YrSold'

col=["BsmtFinSF2","LowQualFinSF","BsmtHalfBath", 'MiscVal', 'YrSold']
#y=x["SalePrice"]

df_train=df_train.drop(col,axis=1)
df_test=df_test.drop(col,axis=1)



#df_train.drop(["SalePrice"],axis=1,inplace=True)

# %%
df_train.shape,df_test.shape
# Out:
# ((1460, 72), (1459, 71))

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 72 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   category
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Alley          1460 non-null   category
#  5   LotShape       1460 non-null   category
#  6   LandContour    1460 non-null   category
#  7   LotConfig      1460 non-null   category
#  8   LandSlope      1460 non-null   category
#  9   Neighborhood   1460 non-null   category
#  10  Condition1     1460 non-null   category
#  11  Condition2     1460 non-null   category
#  12  BldgType       1460 non-null   category
#  13  HouseStyle     1460 non-null   category
#  14  OverallQual    1460 non-null   int64
#  15  OverallCond    1460 non-null   int64
#  16  YearBuilt      1460 non-null   int64
# ...

# %%
for i in df_train.columns:
    print(i)
    print(df_train["%s"%i].value_counts())
    print("\n")
# Out:
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
#
#
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
#
#
# LotFrontage
# 70.049958     259
# 60.000000     143
# 70.000000      70
# 80.000000      69
# 50.000000      57
# 75.000000      53
# 65.000000      44
# 85.000000      40
# 78.000000      25
# 21.000000      23
# 90.000000      23
# 68.000000      19
# 64.000000      19
# 24.000000      19
# 73.000000      18
# 55.000000      17
# 79.000000      17
# 63.000000      17
# 72.000000      17
# 100.000000     16
# 51.000000      15
# 66.000000      15
# 74.000000      15
# 52.000000      14
# 59.000000      13
# 82.000000      12
# 57.000000      12
# 71.000000      12
# 43.000000      12
# 40.000000      12
# ...

# %%
df_train.shape
# Out:
# (1460, 72)

# %%
#####  CATEGORICAL VALUES
cat_features = df_train.select_dtypes(include=['category']).columns



for feature in cat_features:
    data=df_train.copy()
    data.groupby(feature)['SalePrice'].mean().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

#####  ALL SEEM INPORTANT

# %%
df_train.shape,df_test.shape
# Out:
# ((1460, 72), (1459, 71))

# %% [markdown]
# ###  TRANSFORMATIONS

# %%
num_features = df_train.select_dtypes(include=['number']).columns
num_features
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MoSold',
#        'SalePrice'],
#       dtype='object')

# %%
########   DISTRIVUTIONS FOR CONITUNOUS FEATURES
num_features = df_train.select_dtypes(include=['number']).columns
cat_features = df_train.select_dtypes(include=['category']).columns
#num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']   ##3 ONLY SELECTING FEATIURES WHERE VALUES IN IN ARE NOT ZERO


for feature in cat_features:
    data=df_train.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
# right skewed continous : 'LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea' ,"MasVnrArea" , "BsmtFinSF1" , "BsmtUnfSF", "OpenPorchSF"


#left skewed:YearBuilt





########  SalePrice is right skewed

from scipy import stats


from scipy.stats import norm

# norm = a normal continous variable.

log_style = np.log(df_train['SalePrice'])  # log of salesprice

fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
#plt.suptitle('Probability Plots \n', fontsize=18)

print("\n ")
ax1 = sns.distplot(df_train['SalePrice'], color="#FA5858", ax=ax1, fit=norm)
ax1.set_title("\nDistribution of Sales Price with Positive Skewness", fontsize=14)

ax2 = sns.distplot(log_style, color="#58FA82",ax=ax2, fit=norm)
ax2.set_title("\tNormal Distibution with Log Transformations", fontsize=14)



plt.show()
# Out:
# C:\Users\ANTHONY\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ANTHONY\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ANTHONY\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
######  log transformation for right skewed distributions where there is no zero

#########  finding out the columns which dotn have zero
for feature in num_features:
    data=df_train.copy()
    if 0 not in data[feature].unique():
        print(feature)
# Out:
# MSSubClass
# LotFrontage
# LotArea
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# 1stFlrSF
# GrLivArea
# TotRmsAbvGrd
# MoSold
# SalePrice

# %%
######### OUT OF ABOVE ONLY 4 HAVE NON ZERO AND LOG CAN BE APPLIED TO THAT

##LOG TRANSFORMATION --  its skewed as we have seen in EDA

import numpy as np
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']   ##3 ONLY SELECTING 4 FEATIURES WHERE VALUES IN IN ARE NOT ZERO

for feature in num_features:
    df_train[feature]=np.log(df_train[feature])

for feature in num_features:
    df_test[feature]=np.log(df_test[feature])

# %%
######  HISTOGRAM AFTER APPLYING LOG TRANSFORAMTIONS
########   DISTRIVUTIONS FOR CONITUNOUS FEATURES
colo_features = ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']

#num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']   ##3 ONLY SELECTING FEATIURES WHERE VALUES IN IN ARE NOT ZERO


for feature in colo_features:
    data=df_train.copy()
    data[feature].hist(bins=25,color="green")
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title("AFTER LOG-TRANSFORAMTION")
    plt.show()

# %%
#########33 removing SalePrice
y=df_train.SalePrice
df_train=df_train.drop(["SalePrice"],axis=1)
df_train.shape,df_test.shape
# Out:
# ((1460, 71), (1459, 71))

# %%
df_train.shape,df_test.shape
# Out:
# ((1460, 71), (1459, 71))

# %% [markdown]
# ### ONE HOT ENCODING

# %%
Big2=pd.concat([df_train, df_test], sort=False)

pd.set_option("display.max_rows", None, "display.max_columns", None)
Big2.loc[:, Big2.dtypes == 'object'] =\
    Big2.select_dtypes(['object'])\
    .apply(lambda x: x.astype('category'))

non_numeric_features = Big2.select_dtypes(include=['category']).columns


#non_numeric_features = Big2.dtypes[Big2.dtypes == "category"  | Big2.dtypes == "object" ].index

Big2= pd.get_dummies(Big2, columns = non_numeric_features)
Big2

XX=Big2[0:1460]
ZZ=Big2[1460:]
XX.shape,ZZ.shape
# Out:
# ((1460, 292), (1459, 292))

# %%
XX.shape,ZZ.shape
# Out:
# ((1460, 292), (1459, 292))

# %%
non_numeric_features = Big2.select_dtypes(include=['category']).columns
non_numeric_features = Big2.select_dtypes(include=['category']).columns
########  logging as y is skewwed
#The dependent variabel, SalePrice, are skewed and heavy-tailed distribution. 

#######  cehck kaggle 8 also

Y = np.log1p(y)
Y
# Out:
# 0       12.247699
# 1       12.109016
# 2       12.317171
# 3       11.849405
# 4       12.429220
# 5       11.870607
# 6       12.634606
# 7       12.206078
# 8       11.774528
# 9       11.678448
# 10      11.771444
# 11      12.751303
# 12      11.877576
# 13      12.540761
# 14      11.964007
# 15      11.790565
# 16      11.911708
# 17      11.407576
# 18      11.976666
# 19      11.842236
# 20      12.692506
# 21      11.845110
# 22      12.345839
# 23      11.774528
# 24      11.944714
# 25      12.454108
# 26      11.811555
# 27      12.631344
# 28      12.242891
# 29      11.134604
# 30      10.596660
# 31      11.914055
# 32      12.100162
# 33      12.016733
# 34      12.533580
# 35      12.641100
# 36      11.884496
# 37      11.938200
# 38      11.599112
# 39      11.314487
# 40      11.982935
# 41      12.043560
# 42      11.877576
# 43      11.777219
# 44      11.856522
# 45      12.675767
# 46      12.387089
# 47      12.428019
# 48      11.635152
# 49      11.751950
# ...

# %% [markdown]
# ## hypertuning---> CATBOOST

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]

learning_rate=[float(x) for x in np.linspace(start = 0.1, stop = .99, num = 5)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [2,4,6,8,10,12]

num_trees = [50, 150, 200, 250, 300, 350]

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
max_leaves = [1, 2, 4,6,8]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'learning_rate': learning_rate,
               'max_leaves': max_leaves,
              'loss_function':['MAPE','RMSE','MAE']}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_depth': [2, 4, 6, 8, 10, 12], 'learning_rate': [0.1, 0.3225, 0.545, 0.7675, 0.99], 'max_leaves': [1, 2, 4, 6, 8], 'loss_function': ['MAPE', 'RMSE', 'MAE']}

# %%
###################33  using pipeline  ##############################3

import catboost as ctb
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,RobustScaler,PolynomialFeatures
from sklearn.pipeline import Pipeline



object_feats = df_train.dtypes[df_train.dtypes == "category"].index.tolist()
numeric_feats = df_train.dtypes[df_train.dtypes != "category"].index.tolist()

model=ctb.CatBoostRegressor()

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), object_feats),
        ('num', RobustScaler() , numeric_feats)
    ])

##################################################3
cbr=ctb.CatBoostRegressor()
cbr_randomcv=RandomizedSearchCV(estimator=cbr,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)


clf_cbr = Pipeline(steps=[
                    ('pre', preprocessor),
                    ('cbr_randomcv', cbr_randomcv)
                    ])

clf_cbr.fit(df_train, Y)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\ANTHONY\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.8984609         nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.86405603        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.90967301        nan        nan        nan        nan        nan
# ...

# %%
clf_cbr["cbr_randomcv"]
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=<catboost.core.CatBoostRegressor object at 0x00000196D2F14E80>,
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.1, 0.3225, 0.545,
#                                                           0.7675, 0.99],
#                                         'loss_function': ['MAPE', 'RMSE',
#                                                           'MAE'],
#                                         'max_depth': [2, 4, 6, 8, 10, 12],
#                                         'max_leaves': [1, 2, 4, 6, 8],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=100, verbose=2)

# %%
cbr_randomcv.best_params_
# Out:
# {'n_estimators': 2000,
#  'max_leaves': 4,
#  'max_depth': 2,
#  'loss_function': 'MAPE',
#  'learning_rate': 0.1}

# %%
best_random_grid=cbr_randomcv.best_estimator_
best_random_grid

# %%
#############  GRIDSEARCH


from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_leaves': [cbr_randomcv.best_params_['max_leaves']],
    'max_depth': [cbr_randomcv.best_params_['max_depth']],
    'loss_function': [cbr_randomcv.best_params_['loss_function']],
    'learning_rate': [cbr_randomcv.best_params_['learning_rate'], 
                         cbr_randomcv.best_params_['learning_rate']+ .025 , 
                         cbr_randomcv.best_params_['learning_rate'] - .05],
    'n_estimators': [cbr_randomcv.best_params_['n_estimators'] - 200, cbr_randomcv.best_params_['n_estimators'] - 100, 
                     cbr_randomcv.best_params_['n_estimators'], 
                     cbr_randomcv.best_params_['n_estimators'] + 100, cbr_randomcv.best_params_['n_estimators'] + 200]
}

print(param_grid)
# Out:
# {'max_leaves': [4], 'max_depth': [2], 'loss_function': ['MAPE'], 'learning_rate': [0.1, 0.125, 0.05], 'n_estimators': [1800, 1900, 2000, 2100, 2200]}

# %%
##################33  using pipeline  ##############################3

import catboost as ctb
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,RobustScaler,PolynomialFeatures
from sklearn.pipeline import Pipeline



object_feats = df_train.dtypes[df_train.dtypes == "category"].index.tolist()
numeric_feats = df_train.dtypes[df_train.dtypes != "category"].index.tolist()

model=ctb.CatBoostRegressor()

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), object_feats),
        ('num', RobustScaler() , numeric_feats)
    ])

##################################################3

#### Fit the grid_search to the data
cbr=ctb.CatBoostRegressor()
grid_search=GridSearchCV(estimator=cbr,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)


clf_cbr = Pipeline(steps=[
                    ('pre', preprocessor),
                    ('cbr_gridsearch', grid_search)
                    ])

clf_cbr.fit(df_train, Y)
# Out:
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# 0:	learn: 0.0243096	total: 26.1ms	remaining: 57.4s
# 1:	learn: 0.0230292	total: 29.1ms	remaining: 31.9s
# 2:	learn: 0.0219354	total: 32ms	remaining: 23.5s
# 3:	learn: 0.0210156	total: 34.9ms	remaining: 19.1s
# 4:	learn: 0.0201051	total: 37.7ms	remaining: 16.5s
# 5:	learn: 0.0193870	total: 40.4ms	remaining: 14.8s
# 6:	learn: 0.0187763	total: 42.7ms	remaining: 13.4s
# 7:	learn: 0.0180554	total: 45.3ms	remaining: 12.4s
# 8:	learn: 0.0174145	total: 48.2ms	remaining: 11.7s
# 9:	learn: 0.0166760	total: 50.4ms	remaining: 11s
# 10:	learn: 0.0160882	total: 52.4ms	remaining: 10.4s
# 11:	learn: 0.0156043	total: 54.2ms	remaining: 9.88s
# 12:	learn: 0.0151910	total: 55.7ms	remaining: 9.37s
# 13:	learn: 0.0148513	total: 57.1ms	remaining: 8.91s
# 14:	learn: 0.0144599	total: 58.3ms	remaining: 8.5s
# 15:	learn: 0.0141724	total: 59.9ms	remaining: 8.18s
# 16:	learn: 0.0137449	total: 62.3ms	remaining: 8s
# ...

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1,
#  'loss_function': 'MAPE',
#  'max_depth': 2,
#  'max_leaves': 4,
#  'n_estimators': 2200}

# %% [markdown]
# ### HYPERTUNE LGBM

# %%
import lightgbm as lgb


import numpy as np
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 20)]
# Number of features to consider at every split
boosting_type = ["gbdt", "rf", "dart", "goss"]
    
learning_rate=[float(x) for x in np.linspace(start = 0.05, stop = .8, num = 20)]

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(-1, 1000,20)]

# Minimum number of samples required at each leaf node
num_leaves = [20,30,40,50,60,70,80]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'boosting_type': boosting_type,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'num_leaves': num_leaves}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000], 'boosting_type': ['gbdt', 'rf', 'dart', 'goss'], 'learning_rate': [0.05, 0.08947368421052632, 0.12894736842105264, 0.16842105263157894, 0.20789473684210524, 0.24736842105263157, 0.2868421052631579, 0.32631578947368417, 0.3657894736842105, 0.4052631578947368, 0.44473684210526315, 0.4842105263157894, 0.5236842105263158, 0.5631578947368421, 0.6026315789473684, 0.6421052631578947, 0.6815789473684211, 0.7210526315789474, 0.7605263157894737, 0.8], 'max_depth': [-1, 51, 104, 157, 209, 262, 315, 367, 420, 473, 525, 578, 631, 683, 736, 789, 841, 894, 947, 1000], 'num_leaves': [20, 30, 40, 50, 60, 70, 80]}

# %%
###################33  using pipeline  ##############################3

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,RobustScaler,PolynomialFeatures
from sklearn.pipeline import Pipeline


object_feats = df_train.dtypes[df_train.dtypes == "category"].index.tolist()
numeric_feats = df_train.dtypes[df_train.dtypes != "category"].index.tolist()

#####################
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), object_feats),
        ('num', RobustScaler() , numeric_feats)
    ],remainder='passthrough')

##################################################3
lgbm=lgb.LGBMRegressor()
lgbm_randomcv=RandomizedSearchCV(estimator=lgbm,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)


clf_lgbm = Pipeline(steps=[
                    ('pre', preprocessor),
                    ('lgbm_randomcv', lgbm_randomcv)
                    ])

clf_lgbm.fit(df_train, Y)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\ANTHONY\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [  0.83898175          nan   0.40146393          nan          nan
#   -0.07987674   0.794632            nan   0.87085073   0.6439604
#    0.8678287    0.88467121          nan   0.68359197   0.86291527
#    0.52039278          nan          nan          nan          nan
#    0.83109709   0.88617539   0.88927078          nan   0.86967748
#    0.87927179          nan   0.88548678   0.11115179   0.68359197
#    0.16124352   0.88100014   0.8552266    0.86632708   0.85336163
#    0.88189951   0.80104346          nan   0.87754545          nan
#    0.86987214          nan   0.86484152   0.62787896          nan
#    0.85443015   0.88438608   0.80622884   0.84942584   0.76520329
#           nan   0.84189273   0.8834548    0.88687129   0.82628375
# ...

# %%
lgbm_randomcv.best_params_
# Out:
# {'num_leaves': 20,
#  'n_estimators': 1300,
#  'max_depth': 525,
#  'learning_rate': 0.44473684210526315,
#  'boosting_type': 'dart'}

# %% [markdown]
# ## checking stacking models

# %%
######################

###################3


###########################################################################################################################

import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, ElasticNet, LassoLars, Lasso, RidgeCV
from sklearn.kernel_ridge import KernelRidge



from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,RobustScaler,PolynomialFeatures
from sklearn.feature_selection import SelectFromModel  
from sklearn.ensemble import StackingRegressor



object_feats = df_train.dtypes[df_train.dtypes == "category"].index.tolist()
numeric_feats = df_train.dtypes[df_train.dtypes != "category"].index.tolist()

############## one hot encoding + scaling ####################

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), object_feats),
        ('num', RobustScaler() , numeric_feats)
    ])
############################################## CATBOOST - #######################################################
cbr = ctb.CatBoostRegressor(n_estimators= 2200,
 max_leaves= 4,
 max_depth= 2,
 loss_function= "MAPE",                                              
 learning_rate= 0.1)
clf_cbr = Pipeline(steps=[
                    ('pre', preprocessor),
                    ('ctb', cbr),
                    ])

clf_cbr.fit(df_train, Y)
###################################################  XGBOOST ################################
xg = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)
clf_xg = Pipeline(steps=[
                    ('pre', preprocessor),
                    ('poly', PolynomialFeatures(2)),
                    ('selection', SelectFromModel(estimator=RandomForestRegressor(n_estimators=300, random_state=1))),
                    ('a', xg),
                    ])

#####  SELECT FROM MODEL--> used for feature selection like RFECV and RFE
clf_xg.fit(df_train, Y)

############################################## LGBM - ###################################################

lg = lgb.LGBMRegressor(objective='regression',num_leaves=20,
                              learning_rate=0.44473684210526315, n_estimators=1300,
                              max_bin = 55, bagging_fraction = 0.8,
                              max_depth=525,boosting_type='dart',
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf=6, min_sum_hessian_in_leaf = 11)
clf_lg = Pipeline(steps=[
                    ('pre', preprocessor),
                    ('a', lg),
                    ])

clf_lg.fit(df_train, Y)

############################################# MANY OTHERS- STACKINGCV ###########################################

estimators = [
                ('', RandomForestRegressor(n_estimators=300,random_state=1)),
                ('kernel_ridge', KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)),
                ('Boosting', GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber',random_state=1)),
                ('elasticnet', ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3)),
                ( 'lasso', Lasso(alpha = 0.0005, random_state=1)),
             ]
stack_reg = StackingRegressor(estimators = estimators, final_estimator = RandomForestRegressor(n_estimators = 500 ,random_state=1), n_jobs=-1)



######estimatorslist of (str, estimator):::::Base estimators which will be stacked together
#######final_estimatorestimator::A regressor which will be used to combine the base estimators. The default regressor is a RidgeCV.
######## n_jobsint, default=None:::The number of jobs to run in parallel for fit of all estimators. None means 1 unless in a joblib.parallel_backend context. -1 means using all processors. 
######## https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html

clf = Pipeline(steps=[
                    ('pre', preprocessor),
                    ('a', stack_reg),
                    ])
clf.fit(df_train, Y)

#########################################  MIXING ALL OTHER PREDICTIONS #####################################

predictions = 0.4*np.expm1(clf.predict(df_test)) + 0.2*np.expm1(clf_xg.predict(df_test))+ 0.2*np.expm1(clf_lg.predict(df_test))+0.2*np.expm1(clf_cbr.predict(df_test))
# Out:
# 0:	learn: 0.0243096	total: 15ms	remaining: 32.9s
# 1:	learn: 0.0230292	total: 16.4ms	remaining: 18s
# 2:	learn: 0.0219354	total: 17.3ms	remaining: 12.7s
# 3:	learn: 0.0210156	total: 18.3ms	remaining: 10s
# 4:	learn: 0.0201051	total: 19.2ms	remaining: 8.42s
# 5:	learn: 0.0193870	total: 20.2ms	remaining: 7.37s
# 6:	learn: 0.0187763	total: 21.3ms	remaining: 6.67s
# 7:	learn: 0.0180554	total: 22.3ms	remaining: 6.11s
# 8:	learn: 0.0174145	total: 23.4ms	remaining: 5.69s
# 9:	learn: 0.0166760	total: 24.6ms	remaining: 5.39s
# 10:	learn: 0.0160882	total: 25.5ms	remaining: 5.08s
# 11:	learn: 0.0156043	total: 26.4ms	remaining: 4.82s
# 12:	learn: 0.0151910	total: 27.4ms	remaining: 4.61s
# 13:	learn: 0.0148513	total: 28.3ms	remaining: 4.42s
# 14:	learn: 0.0144599	total: 29.3ms	remaining: 4.26s
# 15:	learn: 0.0141724	total: 30.2ms	remaining: 4.12s
# 16:	learn: 0.0137449	total: 31.1ms	remaining: 3.99s
# 17:	learn: 0.0133797	total: 31.9ms	remaining: 3.87s
# ...

# %%
from sklearn.ensemble import StackingRegressor

stack_reg = StackingRegressor(estimators = estimators, final_estimator = RandomForestRegressor(n_estimators = 500 ,random_state=1), n_jobs=-1)

# %%
predictions = 0.5*np.expm1(clf.predict(df_test)) + 0.25*np.expm1(clf_lg.predict(df_test))+0.25*np.expm1(clf_cbr.predict(df_test))

# %%
                      ########  LOG INVERSE OF SALEPRICE PREDICTIONS
df_ = pd.DataFrame(predictions,columns=['SalePrice'])



df_.index = pd.RangeIndex(1461,1461 + len(df_))
df_.to_csv('kagg100003.csv')

# %%
predictions
# Out:
# array([123180.7805965 , 160336.58875298, 178461.42486228, ...,
#        164880.6417168 , 120269.36004062, 224078.5281544 ])

# %%
predictions


                      ########  LOG INVERSE OF SALEPRICE PREDICTIONS
df_ = pd.DataFrame(predictions,columns=['SalePrice'])



df_.index = pd.RangeIndex(1461,1461 + len(df_))
df_.to_csv('kagg100003.csv')

# %% [markdown]
# ### MODEL BUILDING & PREDICTIONS

# %%
######   catboost
#cat_features=list(range(len(data11.columns)))

#categorical_features_indices = np.where(X.dtypes != np.float)[0]


import catboost as ctb


model_CBR = ctb.CatBoostRegressor()
model_CBR.fit(robust_XX, Y)
print(model_CBR)
y1 = model_CBR.predict(robust_ZZ)
y1

y1 = np.expm1(y1)                      ########  LOG INVERSE OF SALEPRICE PREDICTIONS
# Out:
# Learning rate set to 0.04175
# 0:	learn: 0.3894166	total: 6.25ms	remaining: 6.25s
# 1:	learn: 0.3789493	total: 9.85ms	remaining: 4.92s
# 2:	learn: 0.3687828	total: 13.9ms	remaining: 4.61s
# 3:	learn: 0.3589285	total: 17.9ms	remaining: 4.46s
# 4:	learn: 0.3505989	total: 22.3ms	remaining: 4.44s
# 5:	learn: 0.3420465	total: 26.2ms	remaining: 4.34s
# 6:	learn: 0.3331443	total: 30ms	remaining: 4.25s
# 7:	learn: 0.3251339	total: 33.8ms	remaining: 4.18s
# 8:	learn: 0.3169880	total: 37.6ms	remaining: 4.14s
# 9:	learn: 0.3098991	total: 41.2ms	remaining: 4.08s
# 10:	learn: 0.3026565	total: 44.8ms	remaining: 4.03s
# 11:	learn: 0.2955456	total: 48.3ms	remaining: 3.98s
# 12:	learn: 0.2889863	total: 52.1ms	remaining: 3.96s
# 13:	learn: 0.2820611	total: 57.8ms	remaining: 4.07s
# 14:	learn: 0.2760908	total: 63.3ms	remaining: 4.15s
# 15:	learn: 0.2704380	total: 67.6ms	remaining: 4.16s
# 16:	learn: 0.2649596	total: 70.8ms	remaining: 4.09s
# 17:	learn: 0.2595273	total: 74ms	remaining: 4.04s
# ...

# %%
from sklearn.datasets import make_regression
from lightgbm import LGBMRegressor
#model_CBR.fit(XX, Y)
#print(model_CBR)
#yhat = model_CBR.predict(ZZ)
#yhat
framework = LGBMRegressor()
framework.fit(robust_XX, Y)
y2 = framework.predict(robust_ZZ)
y2


y2 = np.expm1(y2)           ####### inverse log
y2
# Out:
# array([123251.29744843, 156373.47023981, 191386.04279194, ...,
#        161172.80089068, 108220.02591631, 229857.77096827])

# %%
XX.shape,ZZ.shape
# Out:
# ((1460, 292), (1459, 292))

# %%
# evaluate gradient boosting ensemble for regression
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
# define dataset
#X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=7)
# define the model
model = GradientBoostingRegressor()
model.fit(XX,Y)

y3 = model.predict(ZZ)

y3 = np.expm1(y3)
y3
# Out:
# array([122900.71126811, 152084.20581833, 181216.89519864, ...,
#        151524.36954288, 117875.66091242, 237117.50076061])

# %%
# Fitting Random Forest Regression to the dataset
# import the regressor
from sklearn.ensemble import RandomForestRegressor
  
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
  
# fit the regressor with x and y data
regressor.fit(XX,Y)  

y3 = regressor.predict(ZZ)

y3 = np.expm1(y3)
y3
# Out:
# array([125454.31782797, 152230.60255771, 173551.41621493, ...,
#        156756.83006116, 113598.49376525, 230103.15469897])

# %%
y6=(y1+y2)/2

# %%
y6
# Out:
# array([124470.50101116, 161005.61228917, 188154.76895417, ...,
#        163777.02173182, 110825.73664798, 226001.85600988])

# %%
                      ########  LOG INVERSE OF SALEPRICE PREDICTIONS
df_ = pd.DataFrame(y6,columns=['SalePrice'])



df_.index = pd.RangeIndex(1461,1461 + len(df_))
df_.to_csv('kagg100002.csv')

# %%
XX.shape
# Out:
# (1460, 293)

# %%
#######  pycaret

XXX_DF=XX.copy()
XX["SalePrice"]=Y
XXX_DF.shape
# Out:
# (1460, 292)

# %%
from pycaret.regression import *



reg = setup(data=XX, 
            target="SalePrice")
# Out:
# <style  type="text/css" >
# </style><table id="T_fab86f96_ace5_11eb_86d8_bc2fbcffbf57" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fab86f96_ace5_11eb_86d8_bc2fbcffbf57level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fab86f96_ace5_11eb_86d8_bc2fbcffbf57row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_fab86f96_ace5_11eb_86d8_bc2fbcffbf57row0_col1" class="data row0 col1" >8230</td>
#             </tr>
#             <tr>
#                         <th id="T_fab86f96_ace5_11eb_86d8_bc2fbcffbf57level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fab86f96_ace5_11eb_86d8_bc2fbcffbf57row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
# train a decision tree model
dt = create_model('catboost')
# tune hyperparameters of decision tree
tuned_dt = tune_model(dt)
# Out:
# <style  type="text/css" >
# #T_9168d5c3_acef_11eb_9676_bc2fbcffbf57row10_col0,#T_9168d5c3_acef_11eb_9676_bc2fbcffbf57row10_col1,#T_9168d5c3_acef_11eb_9676_bc2fbcffbf57row10_col2,#T_9168d5c3_acef_11eb_9676_bc2fbcffbf57row10_col3,#T_9168d5c3_acef_11eb_9676_bc2fbcffbf57row10_col4,#T_9168d5c3_acef_11eb_9676_bc2fbcffbf57row10_col5{
#             background:  yellow;
#         }</style><table id="T_9168d5c3_acef_11eb_9676_bc2fbcffbf57" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9168d5c3_acef_11eb_9676_bc2fbcffbf57level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
tuned_dt.get_params()
# Out:
# {'depth': 1,
#  'l2_leaf_reg': 50,
#  'loss_function': 'RMSE',
#  'border_count': 254,
#  'verbose': False,
#  'random_strength': 0.1,
#  'task_type': 'CPU',
#  'n_estimators': 260,
#  'random_state': 8230,
#  'eta': 0.4}

# %%
XX=XX.drop("SalePrice",axis=1)

# %%
y6=(y1+y2)/2

                      ########  LOG INVERSE OF SALEPRICE PREDICTIONS
df_ = pd.DataFrame(y6,columns=['SalePrice'])



df_.index = pd.RangeIndex(1461,1461 + len(df_))
df_.to_csv('kagg100002.csv')

# %%
https://medium.com/analytics-vidhya/linear-regression-decision-tree-and-ensemble-learning-applied-to-seoul-housing-prices-830d3493cfdb
