# %% [markdown]
# https://towardsdatascience.com/heart-disease-uci-diagnosis-prediction-b1943ee835a7

# %% [markdown]
# # FINDING EMPLOYEE RETENTION BY
# 1.checking which variables have direct impact on retetion{will they leav company or not}
#
# 2.plotting bar charts on employee ret on salary
#
# 3.plotting bar charts on employee ret on departments
#
# 4.building log reg with variables narrowed down in step 1
#
# 5.finding accuracy of the model

# %% [markdown]
# FEATURE SELECTION READ
# https://towardsdatascience.com/feature-selection-with-pandas-e3690ad8504b

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
address="https://raw.githubusercontent.com/antony-joy/Data_sets/main/HR_employee_ret.csv"
df = pd.read_csv(address)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
address="C:/Users/ANTHONY/Desktop/CSV&XLSX/HR_employee_ret.csv"
df = pd.read_csv(address)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
#finding types of columns.
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
left = df[df.left==1]
left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
retained = df[df.left==0]
retained
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# ...                   ...              ...             ...
# 14206                0.90             0.55               3
# 14207                0.74             0.95               5
# 14208                0.85             0.54               3
# 14209                0.33             0.65               3
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2000                    215                   3              0     0
# 2001                    202                   3              0     0
# ...

# %% [markdown]
# ###  DATA ANALYSIS TO FIND WHICH FEATURES OR COLUMNS ARE NECESSARY...

# %%
df.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# From above table we can draw following conclusions,
#
# **Satisfaction Level**: Satisfaction level seems to be relatively low (0.44) in employees leaving the firm vs the retained ones (0.66)
#
# **Average Monthly Hours**: Average monthly hours are higher in employees leaving the firm (199 vs 207)
#
# **Promotion Last 5 Years**: Employees who are given promotion are likely to be retained at firm

# %% [markdown]
# #### SINCE SALARY AND DEPT ARE CATEGORICAL WE WILL USE CROSSTAB

# %%
dfcrosalary=pd.crosstab(df.salary,df.left)   
dfcrosalary
# Out:
# left       0     1
# salary
# high    1155    82
# low     5144  2172
# medium  5129  1317

# %%
df.groupby(['salary'])["left"].count()
# Out:
# salary
# high      1237
# low       7316
# medium    6446
# Name: left, dtype: int64

# %%
dfpivotsalary=pd.pivot_table(df, index='salary', values=['left'],aggfunc='count')
dfpivotsalary
# Out:
#         left
# salary
# high    1237
# low     7316
# medium  6446

# %%
dfpivotsalary=pd.pivot_table(df, index='salary', columns=['left'],aggfunc='count')
dfpivotsalary
# Out:
#        Department       Work_accident       average_montly_hours        \
# left            0     1             0     1                    0     1
# salary
# high         1155    82          1155    82                 1155    82
# low          5144  2172          5144  2172                 5144  2172
# medium       5129  1317          5129  1317                 5129  1317
#
#        last_evaluation       number_project       promotion_last_5years        \
# left                 0     1              0     1                     0     1
# salary
# high              1155    82           1155    82                  1155    82
# low               5144  2172           5144  2172                  5144  2172
# medium            5129  1317           5129  1317                  5129  1317
#
#        satisfaction_level       time_spend_company
# left                    0     1                  0     1
# salary
# high                 1155    82               1155    82
# ...

# %%
df.salary.value_counts()     #will give only total counts,,, if we need seperate of left and retain then...crosstab
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
dfcrosalary.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
ax = df.plot.bar(x='salary',y='left', rot=0)    #takes a lot of time...better is crosstab
ax
# Out:
# <AxesSubplot:xlabel='salary'>

# %% [markdown]
# Above bar chart shows employees with high salaries are likely to not leave the company

# %%
dfcrossdept=pd.crosstab(df.Department,df.left)
print(dfcrossdept)
# Out:
# left            0     1
# Department
# IT            954   273
# RandD         666   121
# accounting    563   204
# hr            524   215
# management    539    91
# marketing     655   203
# product_mng   704   198
# sales        3126  1014
# support      1674   555
# technical    2023   697

# %%
dfcrossdept.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Department'>

# %% [markdown]
# From above chart there seem to be some impact of department on employee retention but it is not major hence we will ignore department in our analysis
#
# look sales for left and retained............

# %% [markdown]
# ### LETS CREATE A HEAT MAP TOO

# %%
# Python program to generate a heatmap   
# which represents the correlation between   
# columns of panda dataframe 
  
# import required libraries 
import pandas as pd 
import seaborn as sn 
  
# Defining figure size   
# for the output plot  
fig, ax = plt.subplots(figsize = (12, 7)) 
      
cor = df.corr() 
sn.heatmap(cor, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# FILTERING OUT THE CORRELATION TABLE WITH GRETAER THAN .5

# %%
#Correlation with output variable
cor_target = abs(cor["left"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# left    1.0
# Name: left, dtype: float64

# %% [markdown]
# HERE NONE WITH GREAT CORR TO LEFT....

# %% [markdown]
# ### WE UNDERSTOOD FROM DATA ANALYSIS THAT
# From the data analysis so far we can conclude that we will use following variables as independant variables in our model
#
# **Satisfaction Level**
#
# **Average Monthly Hours**
#
# **Promotion Last 5 Years**
#
# **Salary**

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %% [markdown]
# ### Tackle salary dummy variable
#
# Salary has all text data. It needs to be converted to numbers and we will use dummy variable for that. Check my one hot encoding tutorial to understand purpose behind dummy variables.

# %%
salary_dummies = pd.get_dummies(subdf.salary, prefix="salary")
print(salary_dummies)
df_with_dummies = pd.concat([subdf,salary_dummies],axis='columns')

df_with_dummies.head()
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# ...

# %% [markdown]
# Now we need to remove salary column which is text data. It is already replaced by dummy variables so we can safely remove it

# %%
df_with_dummies.drop('salary',axis='columns',inplace=True)
X=df_with_dummies
X.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                0.38                   157                      0
# 1                0.80                   262                      0
# 2                0.11                   272                      0
# 3                0.72                   223                      0
# 4                0.37                   159                      0
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
y = df.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.3)

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.7748571428571429
